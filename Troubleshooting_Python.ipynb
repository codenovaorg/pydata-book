# %% [markdown]
# # Run OS CMD
#
# Use `!` to run OS cmd

# %%
# !pwd

# %%
# !ls

# %%
# !which python

# %%
# !which pip

# %%
# !pip list

# %% [markdown]
# # Helps in Notebook
# - dir() : list attributes and methods for an object
# - help(): help doc

# %%
import numpy as np

# %%
help(np.array)

# %%
dir(np.array)

# %%
# ?pd.array

# %%
import pydoc
print(pydoc.render_doc("pandas.DataFrame", "Help on %s"))

# %% [markdown]
# # Inspect code
#
# - inspect

# %%
import inspect

# %% [markdown]
# ## View Source Code

# %%
import pandas as pd
print(inspect.getsource(pd.DataFrame.head))

# %% [markdown]
# ## View Function Signature

# %%
inspect.signature(pd.read_csv)

# %%
dir(pd)

# %% [markdown]
# # Search Docs

# %%
# ?pd.DataFrame

# %% [markdown]
# # Profiling
#
# - %timeit
# - %prun

# %% [markdown]
# # Offline Document.
# Run this on your local machine's python env.
#
# `python -m pydoc -p 8080`
